# %%
import dspy

lm = dspy.LM(
    model="openrouter/google/gemma-4-31b-it:free",
    api_key=",
    api_base="https://openrouter.ai/api/v1",
)

# %%
dspy.configure(lm=lm)

# Create and use a DSPy module with failover
qa = dspy.ChainOfThought('question -> answer')
response = qa(question="What is DSPy? Please give a brief explanation.")

# %%
print(response)
# Out:
# Prediction(
#     reasoning='The user is asking for a brief explanation of DSPy. I need to define what DSPy is, its core purpose (shifting from prompt engineering to programming), and how it achieves this (optimizing prompts and weights).',
#     answer='**DSPy** (Declarative Self-improving Language Programs) is a framework developed by Stanford University designed to shift the way developers interact with Large Language Models (LLMs). \n\nInstead of relying on manual "prompt engineering"—where users spend hours trial-and-erroring the exact wording of a prompt—DSPy allows you to treat LLM pipelines like **programs**. \n\nKey concepts include:\n1. **Signatures**: You define *what* the task is (e.g., "question -> answer") rather than *how* to phrase the prompt.\n2. **Modules**: Pre-built components (like `ChainOfThought` or `Retrieve`) that handle common LLM patterns.\n3. **Optimizers (Teleprompters)**: This is the core innovation. DSPy can automatically generate and optimize high-quality prompts and few-shot examples based on a small set of training data and a defined metric for success.\n\nIn short, DSPy replaces fragile, hand-written prompts with a systematic, programmable approach to building LLM applications.'
# )
